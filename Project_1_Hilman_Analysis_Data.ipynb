# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/File Colab/student-math.csv')
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# ## Soal No 1

# %%
avgNilai = data[(data['school'] == 'GP')]
avgNilai['G3'].mean()
# Out:
# 10.489971346704872

# %% [markdown]
# ##Soal No 2

# %%
minMaxNilai = data[(data['school'] == 'MS')]
minMaxNilai.groupby(['school']).agg({'G3':['min', 'max']})
# Out:
#         G3
#        min max
# school
# MS       0  19

# %% [markdown]
# ## Soal No 3

# %%
propJk = data.groupby(['sex']).agg({'sex':'count'})
propJk
# Out:
#      sex
# sex
# F    208
# M    187

# %% [markdown]
# ## Soal No 4

# %%
avgNilaiStudyTime = data.groupby(['studytime']).agg({'G3':'mean'})
avgNilaiStudyTime
# Out:
#                   G3
# studytime
# 1          10.047619
# 2          10.171717
# 3          11.400000
# 4          11.259259

# %% [markdown]
# ## Soal No 5

# %%
avgNilaiEduSup = data.groupby(['schoolsup']).agg({'G3':'mean'})
avgNilaiEduSup
# Out:
#                   G3
# schoolsup
# no         10.561047
# yes         9.431373

# %% [markdown]
# ## Soal No 6

# %%
avgAbsen = data.groupby(['failures']).agg({'absences':'mean'})
avgAbsen
# Out:
#           absences
# failures
# 0         5.134615
# 1         9.420000
# 2         6.705882
# 3         4.250000

# %% [markdown]
# ## Soal No 7

# %%
incraseScore = data['G3'] > data['G1']
incraseScore.value_counts()
# Out:
# False    252
# True     143
# dtype: int64

# %% [markdown]
# ## Soal No 8

# %%
extraEdu = data[(data['schoolsup'] == 'yes')]
extraEdu.groupby(['freetime']).agg({'sex':'count'})
# Out:
#           sex
# freetime
# 1           6
# 2           4
# 3          24
# 4          12
# 5           5

# %% [markdown]
# ## Soal No 9

# %%
G1 = 25 / 100 * data['G1'].mean()
G1 = round(G1, 2)
print('Nilai Rata-rata dengan bobot 25% untuk ujian pertama adalah ', G1)
# Out:
# Nilai Rata-rata dengan bobot 25% untuk ujian pertama adalah  2.73

# %%
G2 = 25 / 100 * data['G2'].mean()
G2 = round(G2, 2)
print('Nilai Rata-rata dengan bobot 25% untuk ujian kedua adalah ', G2)
# Out:
# Nilai Rata-rata dengan bobot 25% untuk ujian kedua adalah  2.68

# %%
G3 = 50 / 100 * data['G3'].mean()
G3 = round(G3, 2)
print('Nilai Rata-rata dengan bobot 50% untuk ujian ketiga adalah ', G3)
# Out:
# Nilai Rata-rata dengan bobot 50% untuk ujian ketiga adalah  5.21

# %% [markdown]
# ## Soal No 10

# %%
data.sort_values(by='G3', ascending=False)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 286     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 160     GP   M   17       R     LE3       T     2     1   at_home     other
# 162     GP   M   16       U     LE3       T     1     2     other     other
# 168     GP   F   16       U     GT3       T     2     2     other     other
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 150     GP   M   18       U     LE3       T     1     1     other     other
#
# ...
